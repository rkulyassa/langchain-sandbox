# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
ytt_api = YouTubeTranscriptApi()
transcript = ytt_api.fetch("C-ILK0C3_6w")
transcript
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='and keep in mind this Roosevelt Hotel', start=0.08, duration=4.239), FetchedTranscriptSnippet(text="that's so notorious it is a base of", start=2.08, duration=4.719), FetchedTranscriptSnippet(text='operations for trend which is a vicious', start=4.319, duration=4.721), FetchedTranscriptSnippet(text='vicious gang it is unacceptable that we', start=6.799, duration=4.241), FetchedTranscriptSnippet(text='have these sanctuary city policies i', start=9.04, duration=4.16), FetchedTranscriptSnippet(text='know secretary so this building behind', start=11.04, duration=4.08), FetchedTranscriptSnippet(text="me the Roosevelt Hotel it's a New York", start=13.2, duration=4.32), FetchedTranscriptSnippet(text="City shelter but it's also the base of", start=15.12, duration=4.64), FetchedTranscriptSnippet(text='operations for one of the most dangerous', start=17.52, duration=4.96), FetchedTranscriptSnippet(text='gangs in the entire world and wh
# ...

# %%
for snippet in transcript.snippets:
    print(snippet)
# Out:
# FetchedTranscriptSnippet(text='and keep in mind this Roosevelt Hotel', start=0.08, duration=4.239)
# FetchedTranscriptSnippet(text="that's so notorious it is a base of", start=2.08, duration=4.719)
# FetchedTranscriptSnippet(text='operations for trend which is a vicious', start=4.319, duration=4.721)
# FetchedTranscriptSnippet(text='vicious gang it is unacceptable that we', start=6.799, duration=4.241)
# FetchedTranscriptSnippet(text='have these sanctuary city policies i', start=9.04, duration=4.16)
# FetchedTranscriptSnippet(text='know secretary so this building behind', start=11.04, duration=4.08)
# FetchedTranscriptSnippet(text="me the Roosevelt Hotel it's a New York", start=13.2, duration=4.32)
# FetchedTranscriptSnippet(text="City shelter but it's also the base of", start=15.12, duration=4.64)
# FetchedTranscriptSnippet(text='operations for one of the most dangerous', start=17.52, duration=4.96)
# ...
